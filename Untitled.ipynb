# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as datetime
import datetime as timedelta

# %%
df = pd.read_csv('D:/apple.csv')
df.head()
# Out:
#          date    open    high     low   close     volume  profit or not
# 0  12-12-1980  0.1003  0.1007  0.1003  0.1003  469033600              0
# 1  15-12-1980  0.0955  0.0955  0.0951  0.0951  175884800              1
# 2  16-12-1980  0.0885  0.0885  0.0881  0.0881  105728000              1
# 3  17-12-1980  0.0902  0.0907  0.0902  0.0902   86441600              0
# 4  18-12-1980  0.0929  0.0933  0.0929  0.0929   73449600              0

# %%
df.tail()
# Out:
#              date     open     high     low   close     volume  profit or not
# 10554  24-10-2022  147.185  150.230  146.00  149.45   75569074              0
# 10555  25-10-2022  150.090  152.490  149.36  152.34   73583421              0
# 10556  26-10-2022  150.960  151.990  148.04  149.35   87769611              1
# 10557  27-10-2022  148.070  149.046  144.13  144.80  108110875              1
# 10558  28-10-2022  148.200  157.500  147.82  155.74  162857942              0

# %%
df
# Out:
#                 open      high       low     close     volume  profit or not
# date
# 12-12-1980    0.1003    0.1007    0.1003    0.1003  469033600              0
# 15-12-1980    0.0955    0.0955    0.0951    0.0951  175884800              1
# 16-12-1980    0.0885    0.0885    0.0881    0.0881  105728000              1
# 17-12-1980    0.0902    0.0907    0.0902    0.0902   86441600              0
# 18-12-1980    0.0929    0.0933    0.0929    0.0929   73449600              0
# ...              ...       ...       ...       ...        ...            ...
# 24-10-2022  147.1850  150.2300  146.0000  149.4500   75569074              0
# 25-10-2022  150.0900  152.4900  149.3600  152.3400   73583421              0
# 26-10-2022  150.9600  151.9900  148.0400  149.3500   87769611              1
# 27-10-2022  148.0700  149.0460  144.1300  144.8000  108110875              1
# 28-10-2022  148.2000  157.5000  147.8200  155.7400  162857942              0
#
# [10559 rows x 6 columns]

# %%
df_1= pd.DataFrame(df.close)
df_1
# Out:
#                close
# date
# 12-12-1980    0.1003
# 15-12-1980    0.0951
# 16-12-1980    0.0881
# 17-12-1980    0.0902
# 18-12-1980    0.0929
# ...              ...
# 24-10-2022  149.4500
# 25-10-2022  152.3400
# 26-10-2022  149.3500
# 27-10-2022  144.8000
# 28-10-2022  155.7400
#
# [10559 rows x 1 columns]

# %%
df_1.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_2 = pd.DataFrame(df.open)
df_2
# Out:
#                 open
# date
# 12-12-1980    0.1003
# 15-12-1980    0.0955
# 16-12-1980    0.0885
# 17-12-1980    0.0902
# 18-12-1980    0.0929
# ...              ...
# 24-10-2022  147.1850
# 25-10-2022  150.0900
# 26-10-2022  150.9600
# 27-10-2022  148.0700
# 28-10-2022  148.2000
#
# [10559 rows x 1 columns]

# %%
df_2.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_ = df[(df['close']>1) & (df['open']>1)]

# %%
df_
# Out:
#                 open      high       low     close     volume  profit or not
# date
# 22-03-2000    1.0121    1.1006    1.0028    1.0991  567996800              0
# 23-03-2000    1.0824    1.1463    1.0672    1.0771  562564800              1
# 24-03-2000    1.0858    1.0972    1.0329    1.0572  446913600              1
# 27-03-2000    1.0491    1.1034    1.0434    1.0638  279182400              0
# 28-03-2000    1.0462    1.0824    1.0453    1.0605  202966400              0
# ...              ...       ...       ...       ...        ...            ...
# 24-10-2022  147.1850  150.2300  146.0000  149.4500   75569074              0
# 25-10-2022  150.0900  152.4900  149.3600  152.3400   73583421              0
# 26-10-2022  150.9600  151.9900  148.0400  149.3500   87769611              1
# 27-10-2022  148.0700  149.0460  144.1300  144.8000  108110875              1
# 28-10-2022  148.2000  157.5000  147.8200  155.7400  162857942              0
#
# [4492 rows x 6 columns]

# %%
new = pd.DataFrame(df_.open)

# %%
new.head()
# Out:
#               open
# date
# 22-03-2000  1.0121
# 23-03-2000  1.0824
# 24-03-2000  1.0858
# 27-03-2000  1.0491
# 28-03-2000  1.0462

# %%
new.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
new_1 = df[(df['close']>25) & (df['open']>25)]
new_1.head()
# Out:
#                open     high      low    close     volume  profit or not
# date
# 13-11-2014  25.1988  25.5707  25.1537  25.4287  238091420              0
# 14-11-2014  25.5031  25.7375  25.4806  25.7353  176254380              0
# 17-11-2014  25.7555  26.4340  25.5369  25.6924  186986848              1
# 18-11-2014  25.6812  26.0756  25.6699  26.0260  176895912              0
# 19-11-2014  26.0192  26.0869  25.6496  25.8457  167476640              1

# %%
new_11 = new_1.open

# %%
new_11.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_2019 = df[(df['close']>80) & (df['open']>80)]
df_2019.head()
# Out:
#                open     high      low    close     volume  profit or not
# date
# 03-06-2020  80.0495  80.4292  79.4676  80.1629  104281476              0
# 08-06-2020  81.4278  82.2538  80.7053  82.2192   95407900              0
# 09-06-2020  81.8938  85.2150  81.8617  84.8156  147712364              0
# 10-06-2020  85.7796  87.4735  85.3334  86.9977  165423144              0
# 11-06-2020  86.1273  86.5588  82.7173  82.8209  198270700              1

# %%
df2019 = pd.DataFrame(df_2019.open).plot()
plt.xticks(rotation=45)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.]),
#  [Text(-100.0, 0, '08-06-2022'),
#   Text(0.0, 0, '03-06-2020'),
#   Text(100.0, 0, '27-10-2020'),
#   Text(200.0, 0, '23-03-2021'),
#   Text(300.0, 0, '13-08-2021'),
#   Text(400.0, 0, '05-01-2022'),
#   Text(500.0, 0, '31-05-2022'),
#   Text(600.0, 0, '21-10-2022'),
#   Text(700.0, 0, '')])

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result = adfuller(df_2019['open'])
test_result

#here we can see the data is not stationary as p-value is greater than 0.05
# Out:
# (-2.657677056382566,
#  0.08165264803162015,
#  0,
#  605,
#  {'1%': -3.441204979288887, '5%': -2.86632910370007, '10%': -2.56932048425654},
#  2927.8073203126405)

# %% [markdown]
# ## Differencing

# %%
df_2019['diff'] =df_2019['open'] - df_2019['open'].shift(1) 
 #by using the differencing we shift the data set by 1 downwards for stationary purpose
# Out:
# <ipython-input-57-d56363f15290>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['diff'] =df_2019['open'] - df_2019['open'].shift(1)

# %%
df_2019.head()
# Out:
#                open     high      low    close     volume  profit or not  \
# date
# 03-06-2020  80.0495  80.4292  79.4676  80.1629  104281476              0
# 08-06-2020  81.4278  82.2538  80.7053  82.2192   95407900              0
# 09-06-2020  81.8938  85.2150  81.8617  84.8156  147712364              0
# 10-06-2020  85.7796  87.4735  85.3334  86.9977  165423144              0
# 11-06-2020  86.1273  86.5588  82.7173  82.8209  198270700              1
#
#               diff
# date
# 03-06-2020     NaN
# 08-06-2020  1.3783
# 09-06-2020  0.4660
# 10-06-2020  3.8858
# 11-06-2020  0.3477

# %%
test_result = adfuller(df_2019['diff'].dropna())
test_result
#here the p-value is 0.0 so, we are successful to convert into stationary data
# Out:
# (-26.120694925791724,
#  0.0,
#  0,
#  604,
#  {'1%': -3.4412230283528937,
#   '5%': -2.8663370524631344,
#   '10%': -2.5693247196394893},
#  2928.150952197604)

# %%
df_2019['diff'].plot() 
#here we can see the data is almost stationary
# Out:
# <AxesSubplot:xlabel='date'>

# %%
pd.plotting.autocorrelation_plot
# Out:
# <function pandas.plotting._misc.autocorrelation_plot(series, ax=None, **kwargs)>

# %%
pd.plotting.autocorrelation_plot(df_2019['close'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
df.head(20)
# Out:
#          date    open    high     low   close     volume  profit or not
# 0  1980-12-12  0.1003  0.1007  0.1003  0.1003  469033600              0
# 1  1980-12-15  0.0955  0.0955  0.0951  0.0951  175884800              1
# 2  1980-12-16  0.0885  0.0885  0.0881  0.0881  105728000              1
# 3  1980-12-17  0.0902  0.0907  0.0902  0.0902   86441600              0
# 4  1980-12-18  0.0929  0.0933  0.0929  0.0929   73449600              0
# 5  1980-12-19  0.0985  0.0990  0.0985  0.0985   48630400              0
# 6  1980-12-22  0.1034  0.1038  0.1034  0.1034   37363200              0
# 7  1980-12-23  0.1077  0.1081  0.1077  0.1077   46950400              0
# 8  1980-12-24  0.1134  0.1138  0.1134  0.1134   48003200              0
# 9  1980-12-26  0.1238  0.1243  0.1238  0.1238   55574400              0
# 10 1980-12-29  0.1256  0.1260  0.1256  0.1256   93161600              0
# 11 1980-12-30  0.1230  0.1230  0.1225  0.1225   68880000              1
# 12 1980-12-31  0.1195  0.1195  0.1191  0.1191   35750400              1
# 13 1981-02-01  0.1203  0.1212  0.1203  0.1203   21660800              0
# 14 1981-05-01  0.1181  0.1181  0.1177  0.1177   35728000              1
# 15 1981-06-01  0.1129  0.1129  0.1125  0.1125   45158400              1
# 16 1981-07-01  0.1081  0.1081  0.1077  0.1077   55686400              1
# 17 1981-08-01  0.1059  0.1059  0.1055  0.1055   39827200              1
# 18 1981-09-01  0.1112  0.1116  0.1112  0.1112   21504000              0
# 19 1981-12-01  0.1112  0.1112  0.1103  0.1103   23699200              1

# %%
df_1981 = pd.DataFrame(df[(df['date']>='12-12-1980') & (df['date']<='31-12-1981')])
df_1981
# Out:
#           date    open    high     low   close     volume  profit or not
# 0   1980-12-12  0.1003  0.1007  0.1003  0.1003  469033600              0
# 1   1980-12-15  0.0955  0.0955  0.0951  0.0951  175884800              1
# 2   1980-12-16  0.0885  0.0885  0.0881  0.0881  105728000              1
# 3   1980-12-17  0.0902  0.0907  0.0902  0.0902   86441600              0
# 4   1980-12-18  0.0929  0.0933  0.0929  0.0929   73449600              0
# ..         ...     ...     ...     ...     ...        ...            ...
# 260 1981-12-24  0.0763  0.0767  0.0763  0.0763   28918400              0
# 261 1981-12-28  0.0737  0.0737  0.0728  0.0728   36579200              1
# 262 1981-12-29  0.0741  0.0750  0.0741  0.0741   24236800              0
# 263 1981-12-30  0.0772  0.0776  0.0772  0.0772   32188800              0
# 264 1981-12-31  0.0772  0.0776  0.0772  0.0772   54656000              0
#
# [265 rows x 7 columns]

# %%
df_2018 = pd.DataFrame(df[(df['date']>='01-01-2018') & (df['date']<='31-12-2018')])
df_2019 = pd.DataFrame(df[(df['date']>='01-01-2019') & (df['date']<='31-12-2019')])
df_2020 = pd.DataFrame(df[(df['date']>='01-01-2021') & (df['date']<='31-12-2021')])
df_2021 = pd.DataFrame(df[(df['date']>='01-01-2021') & (df['date']<='31-12-2021')])
df_2022 = pd.DataFrame(df[(df['date']>='01-01-2022') & (df['date']<='31-12-2022')])

# %%
dff = pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022],axis=0)
# dff= np.transpose(dff)

# %%
dff.set_index('date',inplace=True)

# %%
dff
# Out:
#                 open      high       low     close     volume  profit or not
# date
# 2018-02-01   40.5166   41.0262   40.3023   41.0167  102223736              0
# 2018-03-01   41.0810   41.5619   40.9452   41.0095  118071596              1
# 2018-04-01   41.0833   41.3048   40.9738   41.2000   89738388              0
# 2018-05-01   41.2976   41.7572   41.2048   41.6691   94640072              0
# 2018-08-01   41.5143   41.8143   41.4143   41.5143   82271064              0
# ...              ...       ...       ...       ...        ...            ...
# 2022-10-24  147.1850  150.2300  146.0000  149.4500   75569074              0
# 2022-10-25  150.0900  152.4900  149.3600  152.3400   73583421              0
# 2022-10-26  150.9600  151.9900  148.0400  149.3500   87769611              1
# 2022-10-27  148.0700  149.0460  144.1300  144.8000  108110875              1
# 2022-10-28  148.2000  157.5000  147.8200  155.7400  162857942              0
#
# [1215 rows x 6 columns]

# %%
dff.volume.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dff.plot('open')
# Out:
# <AxesSubplot:xlabel='open'>

# %%
dff_v = pd.DataFrame(dff.volume)

# %%
dff_v
# Out:
#                volume
# date
# 2018-02-01  102223736
# 2018-03-01  118071596
# 2018-04-01   89738388
# 2018-05-01   94640072
# 2018-08-01   82271064
# ...               ...
# 2022-10-24   75569074
# 2022-10-25   73583421
# 2022-10-26   87769611
# 2022-10-27  108110875
# 2022-10-28  162857942
#
# [1215 rows x 1 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
dff_v.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
test_ = adfuller(dff['volume'])
test_
# Out:
# (-5.780115850442371,
#  5.149292791542743e-07,
#  9,
#  1205,
#  {'1%': -3.4357884107845953,
#   '5%': -2.863941528023427,
#   '10%': -2.56804861503762},
#  44507.673703249995)
